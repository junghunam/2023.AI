# %% [markdown]
# <a href="https://colab.research.google.com/github/junghunam/2023.AI/blob/main/%EB%8B%A4%ED%95%AD_%EC%84%A0%ED%98%95_%ED%9A%8C%EA%B7%80%EC%97%90_%EB%8C%80%ED%95%9C_%EA%B2%BD%EC%82%AC_%ED%95%98%EA%B0%95%EB%B2%95%EC%9D%98_%EC%9B%90%EB%A6%AC_%EC%A7%91%EA%B0%92_%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1.집값 데이터 읽기**

# %%
import numpy as np

import pandas as pd
from google.colab import files

from google.colab import drive
drive.mount('/content/drive/')

data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/drive/house_price_us.txt', names=['size', 'n_room', 'price'])
print(data)

X = np.c_[data['size'], data['n_room']]
y = data['price']
m = len(data)
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#     size  n_room   price
# 0   2104       3  399900
# 1   1600       3  329900
# 2   2400       3  369000
# 3   1416       2  232000
# 4   3000       4  539900
# 5   1985       4  299900
# 6   1534       3  314900
# 7   1427       3  198999
# 8   1380       3  212000
# 9   1494       3  242500
# 10  1940       4  239999
# 11  2000       3  347000
# 12  1890       3  329999
# 13  4478       5  699900
# 14  1268       3  259900
# 15  2300       4  449900
# 16  1320       2  299900
# 17  1236       3  199900
# 18  2609       4  499998
# 19  3031       4  599000
# 20  1767       3  252900
# 21  1888       2  255000
# 22  1604       3  242900
# 23  1962       4  259900
# 24  3890       3  573900
# 25  1100       3  249900
# 26  1458       3  464500
# 27  2526       3  469000
# 28  2200       3  475000
# 29  2637       3  299900
# 30  1839       2  349900
# ...

# %%
X = (np.array(X)).reshape(m,2)
y = (np.array(y)).reshape(m,1)
print (X.shape, y.shape)
# Out:
# (47, 2) (47, 1)

# %% [markdown]
# 2.그래프 그리기

# %%
import matplotlib.pyplot as plt
plt.plot(X[:,0].reshape(-1), y, 'b.')
plt.xlabel("Size of a house in pyoeng")
plt.ylabel("Price in uck-won")
plt.show()

plt.plot(X[:,1].reshape(-1), y, 'b.')
plt.xlabel("# of rooms")
plt.ylabel("Price in uck-won")
plt.show()

# %% [markdown]
# 3.Feature scaling(normalization)
#
# $ x_i = \frac{x_i-\mu_i}{s_i} $

# %%
def featureNomalization(X):
  mu = np.mean(X, axis=0)
  std = np.std(X, axis=0)

  X_norm = (X - mu) / std

  return X_norm, mu, std

# %%
X, mu, std = featureNomalization(X)
print (X.shape)
# Out:
# (47, 2)

# %% [markdown]
# 4.Gradient descent -> theta

# %%
X_b = np.c_[np.ones((m,1)), X]

learning_rate = 0.01
n_iter = 400

theta = np.zeros((3,1))
gradients = np.zeros((3,1))

for i in range(n_iter):
    gradients = (2.0/m) * X_b.T.dot(X_b.dot(theta) - y)
    theta = theta - learning_rate * gradients
print ("theta:")
print (theta)
# Out:
# theta:
# [[340307.35772969]
#  [107757.47433209]
#  [ -4888.35338493]]

# %% [markdown]
# 5.임의의 집 크기(x_my)에 대한 집값 예측하기

# %%
X_mine = np.array([[890, 2]])
X_mine = (X_mine - mu) / std
print (X_mine)

X_mine_b = np.c_[np.ones((1,1)), X_mine]
y_predict = X_mine_b.dot(theta)
print (y_predict, "달러")
# Out:
# [[-1.41271579 -1.5543919 ]]
# [[195675.08951911]] 달러

# %% [markdown]
# 6.(Optical) 반복 횟수에 따른 비용함수 J(0) 그리기

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def ComputeJ(t0, t1, t2, X, y):
  m = len(X)
  X_b = np.c_[np.ones((m,1)), X]
  theta = np.array([t0, t1, t2])

  cost_vector = X_b.dot(theta) - y

  cost_vector = cost_vector.reshape(-1)

  cost2 = np.square(cost_vector)

  cost_sum = np.sum(cost2) / (2*m)

  return cost_sum

# %%
X = np.c_[data['size'], data['n_room']]
y = data['price']
m = len(data)

X = (np.array(X)).reshape(m,2)
y = (np.array(y)).reshape(m,1)
print (X.shape, y.shape)

X, mu, std = featureNomalization(X)
print (X.shape)
# Out:
# (47, 2) (47, 1)
# (47, 2)

# %%
X_b = np.c_[np.ones((m,1)), X]

learning_rate = 0.01
n_iter = 400

theta = np.random.randn(3,1)
gradients = np.zeros((3,1))

itr_arr = []
cost_arr = []
for i in range(n_iter):
    gradients = (2.0/m) * X_b.T.dot(X_b.dot(theta) - y)
    theta = theta - learning_rate * gradients

    cost = ComputeJ(theta[0], theta[1], theta[2], X, y)
    cost_arr.append(cost)
    itr_arr.append(i)

print("theta:")
print(theta)
# Out:
# theta:
# [[340307.3581651 ]
#  [107757.50052038]
#  [ -4888.37957742]]

# %%
plt.plot(itr_arr, cost_arr)
plt.xlabel("number of iterations")
plt.ylabel("cost J")
plt.show()
